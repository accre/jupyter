# %%
# %%bash
# python3 -m virtualenv py3-data-science
# source py3-data-science/bin/activate
# pip3 install ipykernel numpy scipy matplotlib pandas scikit-learn hdfs
# ipython kernel install --user --name=py3-data-science
# Out:
# Using base prefix '/usr'
# New python executable in /home/frenchwr/py3-data-science/bin/python3
# Also creating executable in /home/frenchwr/py3-data-science/bin/python
# Installing setuptools, pip, wheel...done.
# ...
#   Using cached https://files.pythonhosted.org/packages/7a/de/a03a5c1f8b743675add3c98f1eb877c67bb29c5196ee6ce54e9c839d23cc/ipykernel-4.9.0-py3-none-any.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/26/c5/ed8379c03040146c807b472563df29134505c72e6980a253310368fc1877/numpy-1.15.1-cp34-cp34m-manylinux1_x86_64.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/56/b5/1a47572236785278db0c8a1e7bb4040eebb63b78fbb470b6f5efc357ffcf/scipy-1.1.0-cp34-cp34m-manylinux1_x86_64.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/18/73/f5a1bc0566c3fdcdacdca99ff996723d12c8abf71ca0d72b69d686577978/matplotlib-2.2.3-cp34-cp34m-manylinux1_x86_64.whl
# ...
